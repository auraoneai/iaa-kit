# %% [markdown]
# # Multi-Reviewer Drift
#
# Synthetic tutorial labels only.

# %%
from iaa_kit import fleiss_kappa, krippendorff_alpha
matrix = [[1, 1, 0], [1, 1, 1], [0, 0, 0]]
assert round(fleiss_kappa(matrix), 6) == 0.55
value, low, high = krippendorff_alpha(matrix, scale='ordinal', n_boot=25)
assert low <= value <= high
