# %% [markdown]
# # Basic Pairwise Agreement
#
# Synthetic tutorial labels only.

# %%
from iaa_kit import cohen_kappa, weighted_kappa
labels_a = [1, 1, 0, 0]
labels_b = [1, 0, 0, 0]
assert round(cohen_kappa(labels_a, labels_b), 6) == 0.5
assert weighted_kappa([1, 2, 3], [1, 2, 2], 'quadratic') > 0
